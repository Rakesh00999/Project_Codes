# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## data_06 is the data set (already deleted the constant and no value columns)

# %%
df=pd.read_csv("data_06.csv")

# %%
df=df.drop(['Unnamed: 0','Unnamed: 0.1'],axis=1)

# %%
df.isnull().sum()
# Out:
# "gbifID                               0
# occurrenceID                          0
# class                                 0
# order                                 0
# family                                0
# genus                                11
# species                              52
# taxonRank                             0
# scientificName                        0
# verbatimScientificName                0
# verbatimScientificNameAuthorship      4
# countryCode                           0
# locality                              0
# stateProvince                         0
# occurrenceStatus                      0
# decimalLatitude                     383
# decimalLongitude                     20
# year                                814
# taxonKey                            119
# speciesKey                           36
# basisOfRecord                        17
# institutionCode                       6
# collectionCode                        0
# ...

# %%
# EDA to analyse the dataset
profile=ProfileReport(df,title="Data_Rport01")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vdev&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-01-29 15:04:53.324887&quot;&gt;&lt;title&gt;Data_Rport01&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ### First handling null values of genus using mode() function and according to the family field relation

# %%
df[df['genus'].isnull()]
# Out:
#          "gbifID    occurrenceID           class           order  \
# 305   "685752233  WII00510004505   Magnoliopsida         Fabales
# 306   "685752232  WII00510004504   Magnoliopsida         Fabales
# 578   "685751960  WII00574304216  Polypodiopsida     Marattiales
# 1403  "685751133  WII00460303335      Liliopsida        Arecales
# 1999  "685750537  WII00353402731   Magnoliopsida  Caryophyllales
# 2000  "685750536  WII00438102730   Magnoliopsida  Caryophyllales
# 2001  "685750535  WII00405902729   Magnoliopsida  Caryophyllales
# 2002  "685750534  WII00100502728   Magnoliopsida  Caryophyllales
# 2003  "685750533  WII00378102727   Magnoliopsida  Caryophyllales
# 4550  "685747986  WII00000400039   Magnoliopsida        Ericales
# 4586  "685747950  WII00593000003   Magnoliopsida    Ranunculales
#
#              family genus species taxonRank scientificName  \
# 305        Fabaceae   NaN     NaN    FAMILY       Fabaceae
# 306        Fabaceae   NaN     NaN    FAMILY       Fabaceae
# ...

# %%
df[df['family']=='Fabaceae']
# Out:
#          "gbifID    occurrenceID          class    order    family  \
# 11    "685752527  WII00000905170  Magnoliopsida  Fabales  Fabaceae
# 12    "685752526  WII00001305169  Magnoliopsida  Fabales  Fabaceae
# 13    "685752525  WII00003605168  Magnoliopsida  Fabales  Fabaceae
# 14    "685752524  WII00003105167  Magnoliopsida  Fabales  Fabaceae
# 15    "685752523  WII00004805166  Magnoliopsida  Fabales  Fabaceae
# ...          ...             ...            ...      ...       ...
# 3919  "685748617  WII00445300691  Magnoliopsida  Fabales  Fabaceae
# 3920  "685748616  WII00439800690  Magnoliopsida  Fabales  Fabaceae
# 3921  "685748615  WII00407800689  Magnoliopsida  Fabales  Fabaceae
# 3922  "685748614  WII00338700688  Magnoliopsida  Fabales  Fabaceae
# 3923  "685748613  WII00565300687  Magnoliopsida  Fabales  Fabaceae
#
#              genus                     species taxonRank  \
# 11           Xylia             Xylia xylocarpa   SPECIES
# ...

# %% [markdown]
# ### here fabaceae in family have the null values in genus we will find the mode of genus where
# ### family is fabaceae

# %%
fabaceae_df = df[df['family'] == 'Fabaceae']

# %%
mode = fabaceae_df['genus'].mode()

# %%
mode
# Out:
# 0    Indigofera
# Name: genus, dtype: object

# %% [markdown]
# ### then we just replace Nan values with the mode value and then use loc to update the actual dataframe df

# %%
fabaceae_df['genus']=fabaceae_df['genus'].fillna('Indigofera')

# %%
df.loc[fabaceae_df.index, 'genus'] = fabaceae_df['genus']

# %% [markdown]
# ### Repeating the same steps to fill other labels in the genus and then similarly with species field

# %%
Marattiaceae_df = df[df['family'] == 'Marattiaceae']
mode =Marattiaceae_df['genus'].mode()
mode
# Out:
# 0    Angiopteris
# Name: genus, dtype: object

# %%
Marattiaceae_df['genus']=Marattiaceae_df['genus'].fillna('Angiopteris')
df.loc[Marattiaceae_df.index, 'genus'] = Marattiaceae_df['genus']

# %%
df.loc[Marattiaceae_df.index, 'genus'] = Marattiaceae_df['genus']

# %%
df.isnull().sum()
# Out:
# "gbifID                               0
# occurrenceID                          0
# class                                 0
# order                                 0
# family                                0
# genus                                 8
# species                              52
# taxonRank                             0
# scientificName                        0
# verbatimScientificName                0
# verbatimScientificNameAuthorship      4
# countryCode                           0
# locality                              0
# stateProvince                         0
# occurrenceStatus                      0
# decimalLatitude                     383
# decimalLongitude                     20
# year                                814
# taxonKey                            119
# speciesKey                           36
# basisOfRecord                        17
# institutionCode                       6
# collectionCode                        0
# ...

# %%
df[df['genus'].isnull()]
# Out:
#          "gbifID    occurrenceID          class           order  \
# 1403  "685751133  WII00460303335     Liliopsida        Arecales
# 1999  "685750537  WII00353402731  Magnoliopsida  Caryophyllales
# 2000  "685750536  WII00438102730  Magnoliopsida  Caryophyllales
# 2001  "685750535  WII00405902729  Magnoliopsida  Caryophyllales
# 2002  "685750534  WII00100502728  Magnoliopsida  Caryophyllales
# 2003  "685750533  WII00378102727  Magnoliopsida  Caryophyllales
# 4550  "685747986  WII00000400039  Magnoliopsida        Ericales
# 4586  "685747950  WII00593000003  Magnoliopsida    Ranunculales
#
#              family genus species taxonRank scientificName  \
# 1403      Arecaceae   NaN     NaN    FAMILY      Arecaceae
# 1999  Amaranthaceae   NaN     NaN    FAMILY  Amaranthaceae
# 2000  Amaranthaceae   NaN     NaN    FAMILY  Amaranthaceae
# 2001  Amaranthaceae   NaN     NaN    FAMILY  Amaranthaceae
# 2002  Amaranthaceae   NaN     NaN    FAMILY  Amaranthaceae
# ...

# %%
Amaranthaceae_df = df[df['family'] == 'Amaranthaceae']
mode =Amaranthaceae_df['genus'].mode()
mode
# Out:
# 0    Alternanthera
# Name: genus, dtype: object

# %%
Amaranthaceae_df['genus']=Amaranthaceae_df['genus'].fillna('Alternanthera')
df.loc[Amaranthaceae_df.index, 'genus'] = Amaranthaceae_df['genus']

# %%
df[df['genus'].isnull()]
# Out:
#          "gbifID    occurrenceID          class         order         family  \
# 1403  "685751133  WII00460303335     Liliopsida      Arecales      Arecaceae
# 4550  "685747986  WII00000400039  Magnoliopsida      Ericales  Polemoniaceae
# 4586  "685747950  WII00593000003  Magnoliopsida  Ranunculales  Ranunculaceae
#
#      genus species taxonRank scientificName  \
# 1403   NaN     NaN    FAMILY      Arecaceae
# 4550   NaN     NaN    FAMILY  Polemoniaceae
# 4586   NaN     NaN    FAMILY  Ranunculaceae
#
#                     verbatimScientificName  ...  \
# 1403                       Phoenix humilis  ...
# 4550  Plemonium caeruleum var. himalayanum  ...
# 4586                    Aqilegia pubiflora  ...
#
#                            decimalLatitude decimalLongitude  year taxonKey  \
# 1403                             11.780441        76.468304  1985   7681.0
# 4550  4a19e429-8f13-478e-86d7-93adb7534524        34.129334     7   1989.0
# ...

# %%
Arecaceae_df = df[df['family'] == 'Arecaceae']
mode =Arecaceae_df['genus'].mode()
mode
# Out:
# 0    Calamus
# Name: genus, dtype: object

# %%
Arecaceae_df['genus']=Arecaceae_df['genus'].fillna('Calamus')
df.loc[Arecaceae_df.index, 'genus'] = Arecaceae_df['genus']

# %%
Polemoniaceae_df = df[df['family'] == 'Polemoniaceae']
mode =Polemoniaceae_df['species'].mode()

# %%
mode
# Out:
# Series([], Name: species, dtype: object)

# %%
Polemoniaceae_df['species']=Polemoniaceae_df['species'].fillna('Polemonium')
df.loc[Polemoniaceae_df.index, 'species'] = Polemoniaceae_df['species']

# %%
df.isnull().sum()
# Out:
# "gbifID                               0
# occurrenceID                          0
# class                                 0
# order                                 0
# family                                0
# genus                                 2
# species                              51
# taxonRank                             0
# scientificName                        0
# verbatimScientificName                0
# verbatimScientificNameAuthorship      4
# countryCode                           0
# locality                              0
# stateProvince                         0
# occurrenceStatus                      0
# decimalLatitude                     383
# decimalLongitude                     20
# year                                814
# taxonKey                            119
# speciesKey                           36
# basisOfRecord                        17
# institutionCode                       6
# collectionCode                        0
# ...

# %%
Polemoniaceae_df['genus']=Polemoniaceae_df['genus'].fillna('Polemonium caeruleum')
df.loc[Polemoniaceae_df.index, 'genus'] = Polemoniaceae_df['genus']

# %%
df[df['genus'].isnull()]
# Out:
#          "gbifID    occurrenceID          class         order         family  \
# 4586  "685747950  WII00593000003  Magnoliopsida  Ranunculales  Ranunculaceae
#
#      genus species taxonRank scientificName verbatimScientificName  ...  \
# 4586   NaN     NaN    FAMILY  Ranunculaceae     Aqilegia pubiflora  ...
#
#                            decimalLatitude decimalLongitude year taxonKey  \
# 4586  4a19e429-8f13-478e-86d7-93adb7534524        30.721575    6   1986.0
#
#      speciesKey basisOfRecord     institutionCode collectionCode  \
# 4586     2410.0           NaN  PRESERVED_SPECIMEN            WII
#
#       catalogNumber  dateIdentified
# 4586    PlantsofWII    W.A. Rodgers
#
# [1 rows x 25 columns]

# %%
Ranunculaceae_df = df[df['family'] == 'Ranunculaceae']
mode =Ranunculaceae_df['genus'].mode()
mode
# Out:
# 0    Clematis
# Name: genus, dtype: object

# %%
Ranunculaceae_df['genus']=Ranunculaceae_df['genus'].fillna('Clematis')
df.loc[Ranunculaceae_df.index, 'genus'] = Ranunculaceae_df['genus']

# %%
df.isnull().sum()
# Out:
# "gbifID                               0
# occurrenceID                          0
# class                                 0
# order                                 0
# family                                0
# genus                                 0
# species                              51
# taxonRank                             0
# scientificName                        0
# verbatimScientificName                0
# verbatimScientificNameAuthorship      4
# countryCode                           0
# locality                              0
# stateProvince                         0
# occurrenceStatus                      0
# decimalLatitude                     383
# decimalLongitude                     20
# year                                814
# taxonKey                            119
# speciesKey                           36
# basisOfRecord                        17
# institutionCode                       6
# collectionCode                        0
# ...

# %%
Amaranthaceae_df = df[df['family'] == 'Amaranthaceae']
mode =Amaranthaceae_df['species'].mode()
mode
# Out:
# 0    Alternanthera sessilis
# Name: species, dtype: object

# %%
Amaranthaceae_df['genus']=Amaranthaceae_df['genus'].fillna('Alternanthera sessilis')
df.loc[Amaranthaceae_df.index, 'genus'] = Amaranthaceae_df['genus']

# %%
Ranunculaceae_df = df[df['family'] == 'Ranunculaceae']
mode =Ranunculaceae_df['species'].mode()
mode
# Out:
# 0    Clematis javana
# Name: species, dtype: object

# %%
Ranunculaceae_df['species']=Ranunculaceae_df['species'].fillna('Clematis javana')
df.loc[Ranunculaceae_df.index, 'species'] = Ranunculaceae_df['species']

# %%
Arecaceae_df = df[df['family'] == 'Arecaceae']
mode =Arecaceae_df['genus'].mode()
mode
# Out:
# 0    Calamus
# Name: genus, dtype: object

# %%
Arecaceae_df['species']=Arecaceae_df['species'].fillna('Calamus')
df.loc[Arecaceae_df.index, 'species'] = Arecaceae_df['species']

# %%
df.isnull().sum()
# Out:
# "gbifID                               0
# occurrenceID                          0
# class                                 0
# order                                 0
# family                                0
# genus                                 0
# species                              48
# taxonRank                             0
# scientificName                        0
# verbatimScientificName                0
# verbatimScientificNameAuthorship      4
# countryCode                           0
# locality                              0
# stateProvince                         0
# occurrenceStatus                      0
# decimalLatitude                     383
# decimalLongitude                     20
# year                                814
# taxonKey                            119
# speciesKey                           36
# basisOfRecord                        17
# institutionCode                       6
# collectionCode                        0
# ...

# %%
df[df['species'].isnull()]
# Out:
#          "gbifID    occurrenceID           class           order  \
# 26    "685752512  WII00008805155   Magnoliopsida     Brassicales
# 107   "685752431  WII00429404910   Magnoliopsida         Fabales
# 158   "685752380  WII00490904655   Magnoliopsida        Lamiales
# 305   "685752233  WII00510004505   Magnoliopsida         Fabales
# 306   "685752232  WII00510004504   Magnoliopsida         Fabales
# 509   "685752029  WII00490304287      Liliopsida     Alismatales
# 578   "685751960  WII00574304216  Polypodiopsida     Marattiales
# 646   "685751892  WII00495304148  Polypodiopsida     Marattiales
# 1383  "685751153  WII00293903355      Liliopsida     Alismatales
# 1468  "685751068  WII00854103270      Liliopsida    Dioscoreales
# 1469  "685751067  WII00854103269      Liliopsida    Dioscoreales
# 1471  "685751065  WII00418003267      Liliopsida        Liliales
# 1498  "685751038  WII00577903239      Liliopsida     Asparagales
# ...

# %%
Clerodendrum_df = df[df['family'] == 'Lamiaceae']
mode =Clerodendrum_df['species'].mode()
mode
# Out:
# 0           Origanum vulgare
# 1    Pogostemon benghalensis
# Name: species, dtype: object

# %%
Clerodendrum_df
# Out:
#          "gbifID    occurrenceID          class     order     family  \
# 105   "685752433  WII00334604912  Magnoliopsida  Lamiales  Lamiaceae
# 106   "685752432  WII00334604911  Magnoliopsida  Lamiales  Lamiaceae
# 152   "685752386  WII00012404661  Magnoliopsida  Lamiales  Lamiaceae
# 153   "685752385  WII00609004660  Magnoliopsida  Lamiales  Lamiaceae
# 154   "685752384  WII00609004659  Magnoliopsida  Lamiales  Lamiaceae
# ...          ...             ...            ...       ...        ...
# 2248  "685750288  WII00365702479  Magnoliopsida  Lamiales  Lamiaceae
# 2249  "685750287  WII00366602478  Magnoliopsida  Lamiales  Lamiaceae
# 2250  "685750286  WII00284902477  Magnoliopsida  Lamiales  Lamiaceae
# 2251  "685750285  WII00404202476  Magnoliopsida  Lamiales  Lamiaceae
# 3495  "685749041  WII00167301146  Magnoliopsida  Lamiales  Lamiaceae
#
#                   genus                    species taxonRank  \
# 105       Leucosceptrum        Leucosceptrum canum   SPECIES
# ...

# %%
Clerodendrum_df['species']=Clerodendrum_df['species'].fillna('Origanum vulgare')
df.loc[Clerodendrum_df.index, 'species'] = Clerodendrum_df['species']

# %%
Alternanthera_df=df[df['genus']=='Alternanthera']
mode=Alternanthera_df['species'].mode()
mode
# Out:
# 0    Alternanthera sessilis
# Name: species, dtype: object

# %%
Alternanthera_df['species']=Alternanthera_df['species'].fillna('Alternanthera sessilis')
df.loc[Alternanthera_df.index, 'species'] = Alternanthera_df['species']

# %%
df.isnull().sum()
# Out:
# "gbifID                               0
# occurrenceID                          0
# class                                 0
# order                                 0
# family                                0
# genus                                 0
# species                              24
# taxonRank                             0
# scientificName                        0
# verbatimScientificName                0
# verbatimScientificNameAuthorship      4
# countryCode                           0
# locality                              0
# stateProvince                         0
# occurrenceStatus                      0
# decimalLatitude                     383
# decimalLongitude                     20
# year                                814
# taxonKey                            119
# speciesKey                           36
# basisOfRecord                        17
# institutionCode                       6
# collectionCode                        0
# ...

# %%
df[df['species'].isnull()]
# Out:
#          "gbifID    occurrenceID           class         order         family  \
# 26    "685752512  WII00008805155   Magnoliopsida   Brassicales    Capparaceae
# 107   "685752431  WII00429404910   Magnoliopsida       Fabales       Fabaceae
# 305   "685752233  WII00510004505   Magnoliopsida       Fabales       Fabaceae
# 306   "685752232  WII00510004504   Magnoliopsida       Fabales       Fabaceae
# 509   "685752029  WII00490304287      Liliopsida   Alismatales        Araceae
# 578   "685751960  WII00574304216  Polypodiopsida   Marattiales   Marattiaceae
# 646   "685751892  WII00495304148  Polypodiopsida   Marattiales   Marattiaceae
# 1383  "685751153  WII00293903355      Liliopsida   Alismatales        Araceae
# 1468  "685751068  WII00854103270      Liliopsida  Dioscoreales  Dioscoreaceae
# 1469  "685751067  WII00854103269      Liliopsida  Dioscoreales  Dioscoreaceae
# 1471  "685751065  WII00418003267      Liliopsida      Liliales      Liliaceae
# ...

# %%
Liliopsida_df=df[df['class']=='Liliopsida']
mode=Liliopsida_df['species'].mode()
mode
# Out:
# 0    Dichanthium annulatum
# Name: species, dtype: object

# %%
Liliopsida_df['species']=Liliopsida_df['species'].fillna('Dichanthium annulatum')
df.loc[Liliopsida_df.index, 'species'] = Liliopsida_df['species']

# %%
Magnoliopsida_df=df[df['class']=='Magnoliopsida']
mode=Magnoliopsida_df['species'].mode()
mode
# Out:
# 0    Origanum vulgare
# Name: species, dtype: object

# %%
Magnoliopsida_df['species']=Magnoliopsida_df['species'].fillna('Origanum vulgare')
df.loc[Magnoliopsida_df.index, 'species'] = Magnoliopsida_df['species']

# %%
df.isnull().sum()
# Out:
# "gbifID                               0
# occurrenceID                          0
# class                                 0
# order                                 0
# family                                0
# genus                                 0
# species                               2
# taxonRank                             0
# scientificName                        0
# verbatimScientificName                0
# verbatimScientificNameAuthorship      4
# countryCode                           0
# locality                              0
# stateProvince                         0
# occurrenceStatus                      0
# decimalLatitude                     383
# decimalLongitude                     20
# year                                814
# taxonKey                            119
# speciesKey                           36
# basisOfRecord                        17
# institutionCode                       6
# collectionCode                        0
# ...

# %%
df[df['species'].isnull()]
# Out:
#         "gbifID    occurrenceID           class        order        family  \
# 578  "685751960  WII00574304216  Polypodiopsida  Marattiales  Marattiaceae
# 646  "685751892  WII00495304148  Polypodiopsida  Marattiales  Marattiaceae
#
#            genus species taxonRank      scientificName verbatimScientificName  \
# 578  Angiopteris     NaN    FAMILY        Marattiaceae      Marattia fraxinea
# 646  Angiopteris     NaN     GENUS  Angiopteris Hoffm.        Angiopteris sp.
#
#      ... decimalLatitude decimalLongitude  year   taxonKey speciesKey  \
# 578  ...       22.461405        78.430281  1987     6628.0        NaN
# 646  ...        8.497334        77.483477  1986  2650108.0        NaN
#
#           basisOfRecord institutionCode collectionCode   catalogNumber  \
# 578  PRESERVED_SPECIMEN             WII    PlantsofWII  WII00574304216
# 646  PRESERVED_SPECIMEN             WII    PlantsofWII  WII00495304148
#
#           dateIdentified
# 578  1987-03-01T00:00:00
# ...

# %%
Angiopteris_df=df[df['class']=='Polypodiopsida']

# %%
mode=Angiopteris_df['species'].mode()
mode
# Out:
# 0    Equisetum ramosissimum
# Name: species, dtype: object

# %%
Angiopteris_df['species']=Angiopteris_df['species'].fillna('Equisetum ramosissimum')
df.loc[Angiopteris_df.index, 'species'] =Angiopteris_df['species']

# %%
df.isnull().sum()
# Out:
# "gbifID                               0
# occurrenceID                          0
# class                                 0
# order                                 0
# family                                0
# genus                                 0
# species                               0
# taxonRank                             0
# scientificName                        0
# verbatimScientificName                0
# verbatimScientificNameAuthorship      4
# countryCode                           0
# locality                              0
# stateProvince                         0
# occurrenceStatus                      0
# decimalLatitude                     383
# decimalLongitude                     20
# year                                814
# taxonKey                            119
# speciesKey                           36
# basisOfRecord                        17
# institutionCode                       6
# collectionCode                        0
# ...

# %%
df.to_csv("data_08.csv")

# %% [markdown]
# ## Cleaning the data in year and handling its null values

# %%
new_df=pd.read_csv("C:/Users/rakes/Desktop/data_08.csv")

# %%
new_df.isnull().sum()
# Out:
# Unnamed: 0                            0
# "gbifID                               0
# occurrenceID                          0
# class                                 0
# order                                 0
# family                                0
# genus                                 0
# species                               0
# taxonRank                             0
# scientificName                        0
# verbatimScientificName                0
# verbatimScientificNameAuthorship      4
# countryCode                           0
# locality                              0
# stateProvince                         0
# occurrenceStatus                      0
# decimalLatitude                     383
# decimalLongitude                     20
# year                                814
# taxonKey                            119
# speciesKey                           36
# basisOfRecord                        17
# institutionCode                       6
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4589 entries, 0 to 4588
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        4589 non-null   int64
#  1   "gbifID                           4589 non-null   object
#  2   occurrenceID                      4589 non-null   object
#  3   class                             4589 non-null   object
#  4   order                             4589 non-null   object
#  5   family                            4589 non-null   object
#  6   genus                             4589 non-null   object
#  7   species                           4589 non-null   object
#  8   taxonRank                         4589 non-null   object
#  9   scientificName                    4589 non-null   object
#  10  verbatimScientificName            4589 non-null   object
# ...

# %%
def digit(x):
    if (len(str(x))!=4):
        return True
new_df['digit']=new_df['year'].apply(digit)

# %%
y_def=new_df.loc[new_df['digit']==True]

# %%
y_def
# Out:
#       Unnamed: 0     "gbifID    occurrenceID          class         order  \
# 5              5  "685752533  WII00005605176  Magnoliopsida   Gentianales
# 17            17  "685752521  WII00006205164  Magnoliopsida    Sapindales
# 27            27  "685752511  WII00541905115  Magnoliopsida     Solanales
# 28            28  "685752510  WII00547005114  Magnoliopsida    Sapindales
# 29            29  "685752509  WII00000005113  Magnoliopsida       Rosales
# ...          ...         ...             ...            ...           ...
# 4584        4584  "685747952  WII00466500005  Magnoliopsida  Ranunculales
# 4585        4585  "685747951  WII00432900004  Magnoliopsida  Ranunculales
# 4586        4586  "685747950  WII00593000003  Magnoliopsida  Ranunculales
# 4587        4587  "685747949  WII00000300002  Magnoliopsida  Ranunculales
# 4588        4588  "685747948  WII00000200001  Magnoliopsida  Ranunculales
#
#              family          genus                     species taxonRank  \
# ...

# %%
y_def['year']=y_def['taxonKey'].copy()

# %%
y_def
# Out:
#       Unnamed: 0     "gbifID    occurrenceID          class         order  \
# 5              5  "685752533  WII00005605176  Magnoliopsida   Gentianales
# 17            17  "685752521  WII00006205164  Magnoliopsida    Sapindales
# 27            27  "685752511  WII00541905115  Magnoliopsida     Solanales
# 28            28  "685752510  WII00547005114  Magnoliopsida    Sapindales
# 29            29  "685752509  WII00000005113  Magnoliopsida       Rosales
# ...          ...         ...             ...            ...           ...
# 4584        4584  "685747952  WII00466500005  Magnoliopsida  Ranunculales
# 4585        4585  "685747951  WII00432900004  Magnoliopsida  Ranunculales
# 4586        4586  "685747950  WII00593000003  Magnoliopsida  Ranunculales
# 4587        4587  "685747949  WII00000300002  Magnoliopsida  Ranunculales
# 4588        4588  "685747948  WII00000200001  Magnoliopsida  Ranunculales
#
#              family          genus                     species taxonRank  \
# ...

# %%
y_def['taxonKey']=y_def['speciesKey'].copy()

y_def['speciesKey']=y_def['basisOfRecord'].copy()
y_def['basisOfRecord']=y_def['institutionCode'].copy()
y_def['institutionCode']=y_def['collectionCode'].copy()

# %%
y_def
# Out:
#       Unnamed: 0     "gbifID    occurrenceID          class         order  \
# 5              5  "685752533  WII00005605176  Magnoliopsida   Gentianales
# 17            17  "685752521  WII00006205164  Magnoliopsida    Sapindales
# 27            27  "685752511  WII00541905115  Magnoliopsida     Solanales
# 28            28  "685752510  WII00547005114  Magnoliopsida    Sapindales
# 29            29  "685752509  WII00000005113  Magnoliopsida       Rosales
# ...          ...         ...             ...            ...           ...
# 4584        4584  "685747952  WII00466500005  Magnoliopsida  Ranunculales
# 4585        4585  "685747951  WII00432900004  Magnoliopsida  Ranunculales
# 4586        4586  "685747950  WII00593000003  Magnoliopsida  Ranunculales
# 4587        4587  "685747949  WII00000300002  Magnoliopsida  Ranunculales
# 4588        4588  "685747948  WII00000200001  Magnoliopsida  Ranunculales
#
#              family          genus                     species taxonRank  \
# ...

# %%
new_df.update(y_def)

# %%
def digit(x):
    if ((len(str(x))==1) or (len(str(x))==2) or (len(str(x))==3)):
        return True
new_df['digit']=new_df['year'].apply(digit)
y_def=new_df.loc[new_df['digit']==True]
yy_def=y_def[y_def['year'].notna()]
yy_def
# Out:
#       Unnamed: 0     "gbifID    occurrenceID          class           order  \
# 38          38.0  "685752500  WII00000005103  Magnoliopsida    Malpighiales
# 42          42.0  "685752496  WII00541105099  Magnoliopsida    Malpighiales
# 43          43.0  "685752495  WII00548705098  Magnoliopsida    Malpighiales
# 44          44.0  "685752494  WII00000005097     Liliopsida    Dioscoreales
# 48          48.0  "685752490  WII00547805093  Magnoliopsida  Caryophyllales
# ...          ...         ...             ...            ...             ...
# 4319      4319.0  "685748217  WII00491500276  Magnoliopsida        Ericales
# 4346      4346.0  "685748190  WII00310900248  Magnoliopsida  Caryophyllales
# 4423      4423.0  "685748113  WII00310600169  Magnoliopsida         Buxales
# 4424      4424.0  "685748112  WII00324700168  Magnoliopsida         Buxales
# 4466      4466.0  "685748070  WII00260200126  Magnoliopsida     Brassicales
#
# ...

# %%
yy_def['year']=yy_def['taxonKey'].copy()
yy_def
# Out:
#       Unnamed: 0     "gbifID    occurrenceID          class           order  \
# 38          38.0  "685752500  WII00000005103  Magnoliopsida    Malpighiales
# 42          42.0  "685752496  WII00541105099  Magnoliopsida    Malpighiales
# 43          43.0  "685752495  WII00548705098  Magnoliopsida    Malpighiales
# 44          44.0  "685752494  WII00000005097     Liliopsida    Dioscoreales
# 48          48.0  "685752490  WII00547805093  Magnoliopsida  Caryophyllales
# ...          ...         ...             ...            ...             ...
# 4319      4319.0  "685748217  WII00491500276  Magnoliopsida        Ericales
# 4346      4346.0  "685748190  WII00310900248  Magnoliopsida  Caryophyllales
# 4423      4423.0  "685748113  WII00310600169  Magnoliopsida         Buxales
# 4424      4424.0  "685748112  WII00324700168  Magnoliopsida         Buxales
# 4466      4466.0  "685748070  WII00260200126  Magnoliopsida     Brassicales
#
# ...

# %%
yy_def['taxonKey']=yy_def['speciesKey'].copy()
yy_def['speciesKey']=yy_def['basisOfRecord'].copy()
yy_def['basisOfRecord']=yy_def['institutionCode'].copy()
yy_def['institutionCode']=yy_def['catalogNumber'].copy()
yy_def
# Out:
#       Unnamed: 0     "gbifID    occurrenceID          class           order  \
# 38          38.0  "685752500  WII00000005103  Magnoliopsida    Malpighiales
# 42          42.0  "685752496  WII00541105099  Magnoliopsida    Malpighiales
# 43          43.0  "685752495  WII00548705098  Magnoliopsida    Malpighiales
# 44          44.0  "685752494  WII00000005097     Liliopsida    Dioscoreales
# 48          48.0  "685752490  WII00547805093  Magnoliopsida  Caryophyllales
# ...          ...         ...             ...            ...             ...
# 4319      4319.0  "685748217  WII00491500276  Magnoliopsida        Ericales
# 4346      4346.0  "685748190  WII00310900248  Magnoliopsida  Caryophyllales
# 4423      4423.0  "685748113  WII00310600169  Magnoliopsida         Buxales
# 4424      4424.0  "685748112  WII00324700168  Magnoliopsida         Buxales
# 4466      4466.0  "685748070  WII00260200126  Magnoliopsida     Brassicales
#
# ...

# %%
y_def.update(yy_def)
new_df.update(y_def)

# %%
new_df.isnull().sum()
# Out:
# Unnamed: 0                             0
# "gbifID                                0
# occurrenceID                           0
# class                                  0
# order                                  0
# family                                 0
# genus                                  0
# species                                0
# taxonRank                              0
# scientificName                         0
# verbatimScientificName                 0
# verbatimScientificNameAuthorship       4
# countryCode                            0
# locality                               0
# stateProvince                          0
# occurrenceStatus                       0
# decimalLatitude                      383
# decimalLongitude                      20
# year                                 103
# taxonKey                               7
# speciesKey                            22
# basisOfRecord                          0
# institutionCode                        0
# ...

# %%
new_df['year'] = new_df['year'].interpolate(method='linear')

# %%
new_df.isnull().sum()
# Out:
# Unnamed: 0                             0
# "gbifID                                0
# occurrenceID                           0
# class                                  0
# order                                  0
# family                                 0
# genus                                  0
# species                                0
# taxonRank                              0
# scientificName                         0
# verbatimScientificName                 0
# verbatimScientificNameAuthorship       4
# countryCode                            0
# locality                               0
# stateProvince                          0
# occurrenceStatus                       0
# decimalLatitude                      383
# decimalLongitude                      20
# year                                 103
# taxonKey                               7
# speciesKey                            22
# basisOfRecord                          0
# institutionCode                        0
# ...

# %%
yy_def=y_def[y_def['year'].isnull()]

# %%
yy_def
# Out:
#       Unnamed: 0     "gbifID    occurrenceID           class         order  \
# 369        369.0  "685752169  WII00616104428   Magnoliopsida      Lamiales
# 370        370.0  "685752168  WII00616104427   Magnoliopsida      Lamiales
# 487        487.0  "685752051  WII00000004309   Magnoliopsida     Asterales
# 541        541.0  "685751997  WII00000004254  Polypodiopsida  Polypodiales
# 569        569.0  "685751969  WII00000004225  Polypodiopsida  Polypodiales
# ...          ...         ...             ...             ...           ...
# 4389      4389.0  "685748147  WII00000700204   Magnoliopsida       Fabales
# 4563      4563.0  "685747973  WII00287600026   Magnoliopsida  Ranunculales
# 4564      4564.0  "685747972  WII00289600025   Magnoliopsida  Ranunculales
# 4565      4565.0  "685747971  WII00287600024   Magnoliopsida  Ranunculales
# 4570      4570.0  "685747966  WII00634000019   Magnoliopsida  Ranunculales
#
# ...

# %%
new_df['year'] = new_df['year'].interpolate(method='linear')

# %%
new_df.isnull().sum()
# Out:
# Unnamed: 0                             0
# "gbifID                                0
# occurrenceID                           0
# class                                  0
# order                                  0
# family                                 0
# genus                                  0
# species                                0
# taxonRank                              0
# scientificName                         0
# verbatimScientificName                 0
# verbatimScientificNameAuthorship       4
# countryCode                            0
# locality                               0
# stateProvince                          0
# occurrenceStatus                       0
# decimalLatitude                      383
# decimalLongitude                      20
# year                                 103
# taxonKey                               7
# speciesKey                            22
# basisOfRecord                          0
# institutionCode                        0
# ...

# %%
new_df.to_csv("data_09.csv")

# %%
df=pd.read_csv("data_09.csv")

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1                           0
# Unnamed: 0                             0
# "gbifID                                0
# occurrenceID                           0
# class                                  0
# order                                  0
# family                                 0
# genus                                  0
# species                                0
# taxonRank                              0
# scientificName                         0
# verbatimScientificName                 0
# verbatimScientificNameAuthorship       4
# countryCode                            0
# locality                               0
# stateProvince                          0
# occurrenceStatus                       0
# decimalLatitude                      383
# decimalLongitude                      20
# year                                 103
# taxonKey                               7
# speciesKey                            22
# basisOfRecord                          0
# ...

# %%
df['taxonKey']=df['taxonKey'].interpolate(method='linear')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1                           0
# Unnamed: 0                             0
# "gbifID                                0
# occurrenceID                           0
# class                                  0
# order                                  0
# family                                 0
# genus                                  0
# species                                0
# taxonRank                              0
# scientificName                         0
# verbatimScientificName                 0
# verbatimScientificNameAuthorship       4
# countryCode                            0
# locality                               0
# stateProvince                          0
# occurrenceStatus                       0
# decimalLatitude                      383
# decimalLongitude                      20
# year                                 103
# taxonKey                               0
# speciesKey                            22
# basisOfRecord                          0
# ...

# %%
similarity = df['taxonKey'].eq(df['speciesKey']).mean()
similarity
# Out:
# 0.0

# %%
df['speciesKey']=df['speciesKey'].interpolate(method='linear')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1                           0
# Unnamed: 0                             0
# "gbifID                                0
# occurrenceID                           0
# class                                  0
# order                                  0
# family                                 0
# genus                                  0
# species                                0
# taxonRank                              0
# scientificName                         0
# verbatimScientificName                 0
# verbatimScientificNameAuthorship       4
# countryCode                            0
# locality                               0
# stateProvince                          0
# occurrenceStatus                       0
# decimalLatitude                      383
# decimalLongitude                      20
# year                                 103
# taxonKey                               0
# speciesKey                            22
# basisOfRecord                          0
# ...

# %%
df=pd.read_csv("C:/Users/rakes/Desktop/data_9.csv")

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1                           0
# Unnamed: 0                             0
# "gbifID                                0
# occurrenceID                           0
# class                                  0
# order                                  0
# family                                 0
# genus                                  0
# species                                0
# taxonRank                              0
# scientificName                         0
# verbatimScientificName                 0
# verbatimScientificNameAuthorship       4
# countryCode                            0
# locality                               0
# stateProvince                          0
# occurrenceStatus                       0
# decimalLatitude                      383
# decimalLongitude                      20
# year                                 103
# taxonKey                               7
# speciesKey                            22
# basisOfRecord                          0
# ...

# %%
df=df.drop(['Unnamed: 0','Unnamed: 0.1'],axis=1)

# %%
df.isnull().sum()
# Out:
# "gbifID                                0
# occurrenceID                           0
# class                                  0
# order                                  0
# family                                 0
# genus                                  0
# species                                0
# taxonRank                              0
# scientificName                         0
# verbatimScientificName                 0
# verbatimScientificNameAuthorship       4
# countryCode                            0
# locality                               0
# stateProvince                          0
# occurrenceStatus                       0
# decimalLatitude                      383
# decimalLongitude                      20
# year                                 103
# taxonKey                               7
# speciesKey                            22
# basisOfRecord                          0
# institutionCode                        0
# collectionCode                         0
# ...
