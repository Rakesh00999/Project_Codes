# %% [markdown]
# ## Explore the data_set

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/rakes/Desktop/data_08.csv")

# %%
df
# Out:
#       Unnamed: 0     "gbifID    occurrenceID          class           order  \
# 0              0  "685752538  WII00004705182  Magnoliopsida         Rosales
# 1              1  "685752537  WII00003305181  Magnoliopsida      Santalales
# 2              2  "685752536  WII00005805180  Magnoliopsida      Santalales
# 3              3  "685752535  WII00003205178  Magnoliopsida  Caryophyllales
# 4              4  "685752534  WII00002805177  Magnoliopsida        Lamiales
# ...          ...         ...             ...            ...             ...
# 4584        4584  "685747952  WII00466500005  Magnoliopsida    Ranunculales
# 4585        4585  "685747951  WII00432900004  Magnoliopsida    Ranunculales
# 4586        4586  "685747950  WII00593000003  Magnoliopsida    Ranunculales
# 4587        4587  "685747949  WII00000300002  Magnoliopsida    Ranunculales
# 4588        4588  "685747948  WII00000200001  Magnoliopsida    Ranunculales
#
# ...

# %% [markdown]
# ## Frequency counts of class of plants

# %%
df_family=df['class']

# %%
# Count the frequency of each plant family
family_counts = df_family.value_counts()

# %%
# Set the threshold for the minimum frequency
threshold = 20
# Select the plant families with a frequency above the threshold
selected_families = family_counts[family_counts > threshold]

# Calculate the total frequency of the remaining plant families
other_families = family_counts[family_counts <= threshold].sum()

# Add the "other" category to the selected plant families
selected_families = selected_families.append(pd.Series([other_families], index=['other']))
# Out:
# C:\Users\rakes\AppData\Local\Temp\ipykernel_3600\1752598110.py:10: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   selected_families = selected_families.append(pd.Series([other_families], index=['other']))

# %% [markdown]
# ## Graph representation

# %%
# Set the labels to the selected plant families
labels = selected_families.index

# Set the values to the frequency of each selected plant family
values = selected_families.values

# Create a bar chart using the labels and values
plt.bar(labels, values)

# Set the chart title
plt.title('Plant Class Distribution')

# Show the plot
plt.show()

# %%
# Select the 'family' column
values = df['class']

# Count the frequency of each value in the column
value_counts = values.value_counts()

# Calculate the mean frequency of the values
mean_frequency = value_counts.mean()

print(mean_frequency)  # Output: 3.0
# Out:
# 655.5714285714286

# %% [markdown]
# ## pie chart

# %%
# Set the labels to the selected plant families
labels = selected_families.index

# Set the values to the frequency of each selected plant family
values = selected_families.values

# Create a pie chart using the labels and values
plt.pie(values, labels=labels)

# Set the chart title
plt.title('Plant Class Distribution')

# Show the plot
plt.show()
